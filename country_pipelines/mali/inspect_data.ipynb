# %% [markdown]
# # I have extracted the data for Q2, Q3 2025, Q4 2025 and Q1 2026
#
# I want to have a look at the extracted data.
# - I want to see that the processing makes sense, that the calculations of the taux, ecart and subsidies make sense.
# - I want to have a look at weird dec/val values that maybe I want to clean
# - I want to have a look at how good the dec/val values are:
#     - Do we have enough data for Q2, Q3, Q4 2025 and Q1 2026?
#     - Is what the centers are reporting consistent?
#     - Are the dec and val values very different?

# %% [markdown]
# ## 1: Initialization
# Read the files

# %%
import polars as pl

# %%
not_cleaned = pl.read_csv(
    "/home/leyregarrido/01_github_repos/VBR-template/country_pipelines/mali/model_june_not_cleaned.csv"
).filter(pl.col("month").is_in(["2025Q2", "2025Q3", "2025Q4", "2026Q1"]))
cleaned = pl.read_csv(
    "/home/leyregarrido/01_github_repos/VBR-template/country_pipelines/mali/model_june_cleaned.csv"
).filter(pl.col("month").is_in(["2025Q2", "2025Q3", "2025Q4", "2026Q1"]))

# %% [markdown]
# ## Check the calculations
#
# I had a look and it looks nice

# %%
not_cleaned.head()
# Out:
# shape: (5, 30)
# ┌─────────────┬────────┬──────────────┬─────┬───┬────────────┬─────────────┬─────────────┬─────────┐
# │ ou          ┆ month  ┆ service      ┆ dec ┆ … ┆ gain_verif ┆ subside_san ┆ subside_ave ┆ quarter │
# │ ---         ┆ ---    ┆ ---          ┆ --- ┆   ┆ ---        ┆ s_verificat ┆ c_verificat ┆ ---     │
# │ str         ┆ str    ┆ str          ┆ f64 ┆   ┆ f64        ┆ ion         ┆ ion         ┆ str     │
# │             ┆        ┆              ┆     ┆   ┆            ┆ ---         ┆ ---         ┆         │
# │             ┆        ┆              ┆     ┆   ┆            ┆ f64         ┆ f64         ┆         │
# ╞═════════════╪════════╪══════════════╪═════╪═══╪════════════╪═════════════╪═════════════╪═════════╡
# │ OFPIxsHOhnu ┆ 2025Q2 ┆ 29.- PMA -   ┆ 0.0 ┆ … ┆ 0.0        ┆ 0.0         ┆ 0.0         ┆ 2025Q2  │
# │             ┆        ┆ Nombre de    ┆     ┆   ┆            ┆             ┆             ┆         │
# │             ┆        ┆ cas suspe…   ┆     ┆   ┆            ┆             ┆             ┆         │
# │ liEMas0AJb0 ┆ 2025Q2 ┆ 08. - PMA -  ┆ 0.0 ┆ … ┆ 0.0        ┆ 0.0         ┆ 0.0         ┆ 2025Q2  │
# │             ┆        ┆ Nbre de      ┆     ┆   ┆            ┆             ┆             ┆         │
# │             ┆        ┆ nouveau-n…   ┆     ┆   ┆            ┆             ┆             ┆         │
# │ Alrz9RZoF4U ┆ 2025Q2 ┆ 04.- PMA -   ┆ 2.0 ┆ … ┆ 0.0        ┆ 1000.0      ┆ 1000.0      ┆ 2025Q2  │
# │             ┆        ┆ Nbre         ┆     ┆   ┆            ┆             ┆             ┆         │
# │             ┆        ┆ Journées     ┆     ┆   ┆            ┆             ┆             ┆         │
# │             ┆        ┆ d’obs…       ┆     ┆   ┆            ┆             ┆             ┆         │
# │ EPezotlggNQ ┆ 2025Q2 ┆ 30.- PMA -   ┆ 5.0 ┆ … ┆ 0.0        ┆ 2250.0      ┆ 2250.0      ┆ 2025Q2  │
# │             ┆        ┆ Nombre de    ┆     ┆   ┆            ┆             ┆             ┆         │
# │             ┆        ┆ cas de ma…   ┆     ┆   ┆            ┆             ┆             ┆         │
# │ lUUSZqKXSRY ┆ 2025Q2 ┆ 13.- PMA -   ┆ 3.0 ┆ … ┆ 0.0        ┆ 2700.0      ┆ 2700.0      ┆ 2025Q2  │
# │             ┆        ┆ Nbre d'accou ┆     ┆   ┆            ┆             ┆             ┆         │
# │             ┆        ┆ chemen…      ┆     ┆   ┆            ┆             ┆             ┆         │
# └─────────────┴────────┴──────────────┴─────┴───┴────────────┴─────────────┴─────────────┴─────────┘

# %% [markdown]
# ## See weird values
#
# In general,
# - There are not many rows where the validated is a lot bigger than the declared
# - There are not many rows that have 0 declared and non-zero validated
#
# But,
# - There are a lot of rows with 0 validated... And I struggle to see if this is because we did not collect the data or because indeed there were 0 validated.

# %%
distributions = not_cleaned.select(
    [
        (((pl.col("dec") == pl.col("val")) & (pl.col("val") != 0)).mean() * 100).alias(
            "pct_all_validated"
        ),
        (((pl.col("val") == 0) & (pl.col("dec") != 0)).mean() * 100).alias("pct_none_validated"),
        (((pl.col("val") != 0) & (pl.col("dec") == 0)).mean() * 100).alias("pct_weird_0_dec"),
        ((pl.col("taux_validation") > 2).mean() * 100).alias("pct_weirdly_high_validated"),
    ]
)
not_cleaned = not_cleaned.with_columns(
    pl.when((pl.col("dec") == pl.col("val")) & (pl.col("val") != 0))
    .then(pl.lit("all_validated"))
    .when((pl.col("val") == 0) & (pl.col("dec") != 0))
    .then(pl.lit("none_validated"))
    .when((pl.col("val") != 0) & (pl.col("dec") == 0))
    .then(pl.lit("weird_0_dec"))
    .when(pl.col("taux_validation") > 2)
    .then(pl.lit("weirdly_high_validated"))
    .otherwise(pl.lit("not_classified"))
    .alias("classification")
)
display(distributions)
# Out:
# shape: (1, 4)
# ┌───────────────────┬────────────────────┬─────────────────┬────────────────────────────┐
# │ pct_all_validated ┆ pct_none_validated ┆ pct_weird_0_dec ┆ pct_weirdly_high_validated │
# │ ---               ┆ ---                ┆ ---             ┆ ---                        │
# │ f64               ┆ f64                ┆ f64             ┆ f64                        │
# ╞═══════════════════╪════════════════════╪═════════════════╪════════════════════════════╡
# │ 31.03609          ┆ 8.676879           ┆ 0.269349        ┆ 0.549533                   │
# └───────────────────┴────────────────────┴─────────────────┴────────────────────────────┘

# %% [markdown]
# ## Check if we have enough data
# - The number of rows per payment mode has not changed much between Q2 and Q3
# - The number of centers that have data in Q3 but not in Q2 is small
# - The number of centers that have data in Q2 but not in Q3 is small
# - The services do not change a lot...
#     - There are some ous that use to have a fair amount of services and now have one -- that is a bit odd, but it does not seem to affect that many of them

# %%
all_quarters = ["2025Q2", "2025Q3", "2025Q4", "2026Q1"]
rows_per_payment = (
    not_cleaned.group_by(["payment_mode", "month"])
    .agg(pl.len().alias("rows"))
    .pivot(index="payment_mode", on="month", values="rows")
)
for q in all_quarters:
    if q not in rows_per_payment.columns:
        rows_per_payment = rows_per_payment.with_columns(pl.lit(None).cast(pl.UInt32).alias(q))
rows_per_payment = rows_per_payment.select(["payment_mode"] + all_quarters)
rows_per_payment.sort("payment_mode")
# Out:
# shape: (12, 5)
# ┌──────────────────────┬────────┬────────┬────────┬────────┐
# │ payment_mode         ┆ 2025Q2 ┆ 2025Q3 ┆ 2025Q4 ┆ 2026Q1 │
# │ ---                  ┆ ---    ┆ ---    ┆ ---    ┆ ---    │
# │ str                  ┆ u32    ┆ u32    ┆ u32    ┆ u32    │
# ╞══════════════════════╪════════╪════════╪════════╪════════╡
# │ paiement_cabinf      ┆ 335    ┆ 424    ┆ 336    ┆ 389    │
# │ paiement_cabmed      ┆ 7084   ┆ 6962   ┆ 5859   ┆ 5873   │
# │ paiement_cabsf       ┆ 495    ┆ 644    ┆ 769    ┆ 921    │
# │ paiement_dispensaire ┆ null   ┆ null   ┆ 4      ┆ 5      │
# │ paiement_ecd         ┆ null   ┆ null   ┆ 46     ┆ null   │
# │ …                    ┆ …      ┆ …      ┆ …      ┆ …      │
# │ paiement_maternite   ┆ 16984  ┆ 18384  ┆ 18647  ┆ 19955  │
# │ paiement_pca         ┆ 1257   ┆ 1284   ┆ 1387   ┆ 1391   │
# │ paiement_pma         ┆ 37213  ┆ 37585  ┆ 37385  ┆ 37619  │
# │ paiement_prive       ┆ 2028   ┆ 2581   ┆ 2971   ┆ 2994   │
# │ paiement_site        ┆ 49171  ┆ 49963  ┆ 53342  ┆ 53779  │
# └──────────────────────┴────────┴────────┴────────┴────────┘

# %%
all_quarters = ["2025Q2", "2025Q3", "2025Q4", "2026Q1"]
ous_in_months = (
    not_cleaned.group_by(["ou", "month"])
    .agg(pl.len().alias("rows"))
    .pivot(index="ou", on="month", values="rows")
)
for q in all_quarters:
    if q not in ous_in_months.columns:
        ous_in_months = ous_in_months.with_columns(pl.lit(None).cast(pl.UInt32).alias(q))

quarters_present = (
    pl.concat_str(
        [
            pl.when(pl.col(q).is_not_null()).then(pl.lit(q)).otherwise(pl.lit(""))
            for q in all_quarters
        ],
        separator=",",
    )
    .str.replace_all(r"^,+|,+$|,,+", ",")
    .str.strip_chars(",")
)

ous_in_months = ous_in_months.with_columns(quarters_present.alias("data_available"))
ous_in_months["data_available"].value_counts(normalize=True).sort("proportion", descending=True)
# Out:
# shape: (15, 2)
# ┌─────────────────────────────┬────────────┐
# │ data_available              ┆ proportion │
# │ ---                         ┆ ---        │
# │ str                         ┆ f64        │
# ╞═════════════════════════════╪════════════╡
# │ 2025Q2,2025Q3,2025Q4,2026Q1 ┆ 0.821987   │
# │ 2025Q4,2026Q1               ┆ 0.043428   │
# │ 2025Q3,2025Q4,2026Q1        ┆ 0.042425   │
# │ 2026Q1                      ┆ 0.030529   │
# │ 2025Q2                      ┆ 0.018776   │
# │ …                           ┆ …          │
# │ 2025Q2,2025Q3,2026Q1        ┆ 0.003583   │
# │ 2025Q3                      ┆ 0.002867   │
# │ 2025Q2,2025Q4               ┆ 0.00258    │
# │ 2025Q3,2025Q4               ┆ 0.001147   │
# │ 2025Q3,2026Q1               ┆ 0.001003   │
# └─────────────────────────────┴────────────┘

# %%
all_quarters = ["2025Q2", "2025Q3", "2025Q4", "2026Q1"]
both_ous = ous_in_months.filter(pl.all_horizontal([pl.col(q).is_not_null() for q in all_quarters]))
both_ous = both_ous.with_columns([pl.col(q).cast(pl.Float64) for q in all_quarters])

# Compare each consecutive pair of quarters
for q_prev, q_next in zip(all_quarters, all_quarters[1:]):
    both_ous = both_ous.with_columns(
        ((pl.col(q_next) - pl.col(q_prev)) / pl.col(q_prev) * 100).alias(
            f"pct_change_{q_prev}_{q_next}"
        ),
        (abs(pl.col(q_next) - pl.col(q_prev))).alias(f"abs_change_{q_prev}_{q_next}"),
    )

pct_cols = [
    f"pct_change_{q_prev}_{q_next}" for q_prev, q_next in zip(all_quarters, all_quarters[1:])
]
abs_cols = [
    f"abs_change_{q_prev}_{q_next}" for q_prev, q_next in zip(all_quarters, all_quarters[1:])
]

summary_rows = []
for col in pct_cols + abs_cols:
    summary_rows.append(
        both_ous.select(
            [
                pl.col(col).min().alias("min"),
                pl.col(col).max().alias("max"),
                pl.col(col).mean().alias("mean"),
                pl.col(col).median().alias("median"),
                pl.col(col).quantile(0.75).alias("q75"),
                pl.lit(col).alias("metric"),
            ]
        )
    )
display(pl.concat(summary_rows).select(["metric", "min", "max", "mean", "median", "q75"]))
# Out:
# shape: (6, 6)
# ┌──────────────────────────┬────────────┬────────┬──────────┬────────┬─────┐
# │ metric                   ┆ min        ┆ max    ┆ mean     ┆ median ┆ q75 │
# │ ---                      ┆ ---        ┆ ---    ┆ ---      ┆ ---    ┆ --- │
# │ str                      ┆ f64        ┆ f64    ┆ f64      ┆ f64    ┆ f64 │
# ╞══════════════════════════╪════════════╪════════╪══════════╪════════╪═════╡
# │ pct_change_2025Q2_2025Q3 ┆ -95.652174 ┆ 2900.0 ┆ 5.681011 ┆ 0.0    ┆ 0.0 │
# │ pct_change_2025Q3_2025Q4 ┆ -88.461538 ┆ 2200.0 ┆ 1.651622 ┆ 0.0    ┆ 0.0 │
# │ pct_change_2025Q4_2026Q1 ┆ -89.473684 ┆ 425.0  ┆ 0.399794 ┆ 0.0    ┆ 0.0 │
# │ abs_change_2025Q2_2025Q3 ┆ 0.0        ┆ 36.0   ┆ 0.443418 ┆ 0.0    ┆ 0.0 │
# │ abs_change_2025Q3_2025Q4 ┆ 0.0        ┆ 38.0   ┆ 0.343854 ┆ 0.0    ┆ 0.0 │
# │ abs_change_2025Q4_2026Q1 ┆ 0.0        ┆ 39.0   ┆ 0.115955 ┆ 0.0    ┆ 0.0 │
# └──────────────────────────┴────────────┴────────┴──────────┴────────┴─────┘

# %% [markdown]
# ## Check how good is the data
# Just like before, the data is okey,
# except for the big amount of rows that have 0 validated
#
# This percetange goes from 20 to 15 if we ignore the rows that have validated null, but it is still fairly high.
# I am not sure how much this will distort the election -- we should probably test it once we can.

# %%
taux_not_cleaned = not_cleaned.select(
    [
        pl.col("taux_validation").mean().alias("taux_mean"),
        pl.col("taux_validation").min().alias("taux_min"),
        pl.col("taux_validation").max().alias("taux_max"),
        pl.col("taux_validation").median().alias("taux_median"),
        pl.col("taux_validation").quantile(0.25).alias("taux_q25"),
        pl.col("taux_validation").quantile(0.33).alias("taux_q33"),
        pl.col("taux_validation").quantile(0.75).alias("taux_q75"),
        ((pl.col("taux_validation") > 2).mean() * 100).alias("pct_weirdly_high_validated"),
        ((pl.col("taux_validation") == 1).mean() * 100).alias("pct_all_validated"),
        ((pl.col("taux_validation") == 0).mean() * 100).alias("pct_none_validated"),
    ]
)
taux_cleaned = cleaned.select(
    [
        pl.col("taux_validation").mean().alias("taux_mean"),
        pl.col("taux_validation").min().alias("taux_min"),
        pl.col("taux_validation").max().alias("taux_max"),
        pl.col("taux_validation").median().alias("taux_median"),
        pl.col("taux_validation").quantile(0.25).alias("taux_q25"),
        pl.col("taux_validation").quantile(0.33).alias("taux_q33"),
        pl.col("taux_validation").quantile(0.75).alias("taux_q75"),
        ((pl.col("taux_validation") > 2).mean() * 100).alias("pct_weirdly_high_validated"),
        ((pl.col("taux_validation") == 1).mean() * 100).alias("pct_all_validated"),
        ((pl.col("taux_validation") == 0).mean() * 100).alias("pct_none_validated"),
    ]
)
taux = pl.concat(
    [
        taux_not_cleaned.with_columns(pl.lit("not_cleaned").alias("dataset")),
        taux_cleaned.with_columns(pl.lit("cleaned").alias("dataset")),
    ]
)
display(taux)
# Out:
# shape: (2, 11)
# ┌───────────┬──────────┬──────────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ taux_mean ┆ taux_min ┆ taux_max ┆ taux_media ┆ … ┆ pct_weird ┆ pct_all_v ┆ pct_none_ ┆ dataset   │
# │ ---       ┆ ---      ┆ ---      ┆ n          ┆   ┆ ly_high_v ┆ alidated  ┆ validated ┆ ---       │
# │ f64       ┆ f64      ┆ f64      ┆ ---        ┆   ┆ alidated  ┆ ---       ┆ ---       ┆ str       │
# │           ┆          ┆          ┆ f64        ┆   ┆ ---       ┆ f64       ┆ f64       ┆           │
# │           ┆          ┆          ┆            ┆   ┆ f64       ┆           ┆           ┆           │
# ╞═══════════╪══════════╪══════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 0.811558  ┆ 0.0      ┆ 282.0    ┆ 1.0        ┆ … ┆ 0.549533  ┆ 53.015336 ┆ 17.098229 ┆ not_clean │
# │           ┆          ┆          ┆            ┆   ┆           ┆           ┆           ┆ ed        │
# │ 0.811558  ┆ 0.0      ┆ 282.0    ┆ 1.0        ┆ … ┆ 0.549533  ┆ 53.015336 ┆ 17.098229 ┆ cleaned   │
# └───────────┴──────────┴──────────┴────────────┴───┴───────────┴───────────┴───────────┴───────────┘
